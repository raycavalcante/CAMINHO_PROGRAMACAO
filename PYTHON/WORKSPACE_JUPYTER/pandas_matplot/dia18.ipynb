# %% [markdown]
# INICIANDO O ASSUNTO SOBRE PANDAS

# %%
import pandas as pd

# %%
# dataframe = pd.DataFrame()
venda = {'data': ['15/02/2021', '16/02/2021'],
         'valor': [500, 300],
         'produto': ['feijao', 'arroz'],
         'qtde': [50, 70],
        }
vendas_df = pd.DataFrame(venda)
print(vendas_df)
print("----------------------------------")
display(vendas_df)
# Out:
#          data  valor produto  qtde
# 0  15/02/2021    500  feijao    50
# 1  16/02/2021    300   arroz    70
# ----------------------------------
#          data  valor produto  qtde
# 0  15/02/2021    500  feijao    50
# 1  16/02/2021    300   arroz    70

# %%
vendas_df = pd.read_excel("Vendas.xlsx")
display(vendas_df)
# Out:
#        Código Venda       Data              ID Loja            Produto  \
# 0                 1 2019-01-01   Iguatemi Esplanada     Sapato Estampa
# 1                 1 2019-01-01   Iguatemi Esplanada           Camiseta
# 2                 1 2019-01-01   Iguatemi Esplanada      Sapato Xadrez
# 3                 2 2019-01-02       Norte Shopping            Relógio
# 4                 2 2019-01-02       Norte Shopping       Chinelo Liso
# ...             ...        ...                  ...                ...
# 93905         65012 2019-11-30  Shopping Vila Velha     Mochila Xadrez
# 93906         65013 2019-11-30    Ribeirão Shopping  Pulseira Listrado
# 93907         65013 2019-11-30    Ribeirão Shopping     Cueca Listrado
# 93908         65014 2019-11-30     Shopping Morumbi     Pulseira Linho
# 93909         65014 2019-11-30     Shopping Morumbi      Casaco Xadrez
#
#        Quantidade  Valor Unitário  Valor Final
# 0               1             358          358
# ...

# %% [markdown]
# 1 - lista 5 primeiras linhas
# 2 - quantidade de linhas e colunas
# 3 - analise dos dados

# %%
display(vendas_df.head(5))
print("-----------------------------------------------------")
display(vendas_df.shape)
print("------------------------------------------------------")
display(vendas_df.describe())
# Out:
#    Código Venda       Data             ID Loja         Produto  Quantidade  \
# 0             1 2019-01-01  Iguatemi Esplanada  Sapato Estampa           1
# 1             1 2019-01-01  Iguatemi Esplanada        Camiseta           2
# 2             1 2019-01-01  Iguatemi Esplanada   Sapato Xadrez           1
# 3             2 2019-01-02      Norte Shopping         Relógio           3
# 4             2 2019-01-02      Norte Shopping    Chinelo Liso           1
#
#    Valor Unitário  Valor Final
# 0             358          358
# 1             180          360
# 2             368          368
# 3             200          600
# 4              71           71
# -----------------------------------
# (93910, 7)
# -----------------------------------
#        Código Venda                           Data    Quantidade  \
# count  93910.000000                          93910  93910.000000
# mean   32464.762155  2019-06-16 23:52:28.265360896      2.166553
# ...

# %% [markdown]
# 1 - pegar a primeira coluna

# %%
produto = vendas_df[['Valor Unitário','ID Loja','Valor Unitário']].head(5)
display(produto)
# Out:
#    Valor Unitário             ID Loja  Valor Unitário
# 0             358  Iguatemi Esplanada             358
# 1             180  Iguatemi Esplanada             180
# 2             368  Iguatemi Esplanada             368
# 3             200      Norte Shopping             200
# 4              71      Norte Shopping              71

# %%
display(vendas_df.loc[1:7])
# Out:
#    Código Venda       Data                     ID Loja        Produto  \
# 1             1 2019-01-01          Iguatemi Esplanada       Camiseta
# 2             1 2019-01-01          Iguatemi Esplanada  Sapato Xadrez
# 3             2 2019-01-02              Norte Shopping        Relógio
# 4             2 2019-01-02              Norte Shopping   Chinelo Liso
# 5             3 2019-01-02  Rio Mar Shopping Fortaleza    Cinto Linho
# 6             5 2019-01-02              Shopping Barra          Calça
# 7             6 2019-01-02         Shopping Ibirapuera  Polo Listrado
#
#    Quantidade  Valor Unitário  Valor Final
# 1           2             180          360
# 2           1             368          368
# 3           3             200          600
# 4           1              71           71
# 5           1             248          248
# 6           1             170          170
# 7           4             149          596

# %%
vendas_Nort_df = vendas_df.loc[vendas_df['ID Loja'] == 'Norte Shopping']
display(vendas_Nort_df)
# Out:
#        Código Venda       Data         ID Loja                 Produto  \
# 3                 2 2019-01-02  Norte Shopping                 Relógio
# 4                 2 2019-01-02  Norte Shopping            Chinelo Liso
# 8                 7 2019-01-02  Norte Shopping  Camisa Gola V Listrado
# 9                 7 2019-01-02  Norte Shopping             Camisa Liso
# 100              73 2019-01-02  Norte Shopping            Cueca Xadrez
# ...             ...        ...             ...                     ...
# 93716         64888 2019-11-30  Norte Shopping             Polo Xadrez
# 93754         64914 2019-11-30  Norte Shopping              Calça Liso
# 93755         64914 2019-11-30  Norte Shopping          Casaco Estampa
# 93756         64914 2019-11-30  Norte Shopping                   Gorro
# 93852         64980 2019-11-30  Norte Shopping           Bermuda Linho
#
#        Quantidade  Valor Unitário  Valor Final
# 3               3             200          600
# ...

# %%
valores_menor_igual_50 = vendas_df.loc[vendas_df['Valor Unitário'] <= 50,['Valor Unitário','Produto','Quantidade']].head(5)
display(valores_menor_igual_50)
# Out:
#     Valor Unitário        Produto  Quantidade
# 27              30           Meia           1
# 43              41    Meia Xadrez           3
# 48              37  Meia Listrado           1
# 49              41    Meia Xadrez           3
# 73              38      Meia Liso           5

# %%
display(vendas_df.loc[5,'Produto'])
# Out:
# 'Cinto Linho'

# %%
valores_menor_igual_50 = vendas_df.loc[vendas_df['Valor Unitário'] <= 50,['ID Loja','Produto','Quantidade','Valor Unitário']].head(5)
display(valores_menor_igual_50)
# Out:
#                        ID Loja        Produto  Quantidade  Valor Unitário
# 27   Parque Dom Pedro Shopping           Meia           1              30
# 43        Shopping Midway Mall    Meia Xadrez           3              41
# 48  Rio Mar Shopping Fortaleza  Meia Listrado           1              37
# 49         Shopping Vila Velha    Meia Xadrez           3              41
# 73    Shopping União de Osasco      Meia Liso           5              38

# %%
display(vendas_df)
# Out:
#        Código Venda       Data              ID Loja            Produto  \
# 0                 1 2019-01-01   Iguatemi Esplanada     Sapato Estampa
# 1                 1 2019-01-01   Iguatemi Esplanada           Camiseta
# 2                 1 2019-01-01   Iguatemi Esplanada      Sapato Xadrez
# 3                 2 2019-01-02       Norte Shopping            Relógio
# 4                 2 2019-01-02       Norte Shopping       Chinelo Liso
# ...             ...        ...                  ...                ...
# 93905         65012 2019-11-30  Shopping Vila Velha     Mochila Xadrez
# 93906         65013 2019-11-30    Ribeirão Shopping  Pulseira Listrado
# 93907         65013 2019-11-30    Ribeirão Shopping     Cueca Listrado
# 93908         65014 2019-11-30     Shopping Morumbi     Pulseira Linho
# 93909         65014 2019-11-30     Shopping Morumbi      Casaco Xadrez
#
#        Quantidade  Valor Unitário  Valor Final
# 0               1             358          358
# ...

# %%
vendas_df['Comissão'] = vendas_df['Valor Final'] * 0.05
display(vendas_df)
# Out:
#        Código Venda       Data              ID Loja            Produto  \
# 0                 1 2019-01-01   Iguatemi Esplanada     Sapato Estampa
# 1                 1 2019-01-01   Iguatemi Esplanada           Camiseta
# 2                 1 2019-01-01   Iguatemi Esplanada      Sapato Xadrez
# 3                 2 2019-01-02       Norte Shopping            Relógio
# 4                 2 2019-01-02       Norte Shopping       Chinelo Liso
# ...             ...        ...                  ...                ...
# 93905         65012 2019-11-30  Shopping Vila Velha     Mochila Xadrez
# 93906         65013 2019-11-30    Ribeirão Shopping  Pulseira Listrado
# 93907         65013 2019-11-30    Ribeirão Shopping     Cueca Listrado
# 93908         65014 2019-11-30     Shopping Morumbi     Pulseira Linho
# 93909         65014 2019-11-30     Shopping Morumbi      Casaco Xadrez
#
#        Quantidade  Valor Unitário  Valor Final  Comissão  Imposto
# ...

# %%
vendas_df.loc[:, "Imposto"] = 0
display(vendas_df)
# Out:
#        Código Venda       Data              ID Loja            Produto  \
# 0                 1 2019-01-01   Iguatemi Esplanada     Sapato Estampa
# 1                 1 2019-01-01   Iguatemi Esplanada           Camiseta
# 2                 1 2019-01-01   Iguatemi Esplanada      Sapato Xadrez
# 3                 2 2019-01-02       Norte Shopping            Relógio
# 4                 2 2019-01-02       Norte Shopping       Chinelo Liso
# ...             ...        ...                  ...                ...
# 93905         65012 2019-11-30  Shopping Vila Velha     Mochila Xadrez
# 93906         65013 2019-11-30    Ribeirão Shopping  Pulseira Listrado
# 93907         65013 2019-11-30    Ribeirão Shopping     Cueca Listrado
# 93908         65014 2019-11-30     Shopping Morumbi     Pulseira Linho
# 93909         65014 2019-11-30     Shopping Morumbi      Casaco Xadrez
#
#        Quantidade  Valor Unitário  Valor Final  Comissão  Imposto
# ...

# %%
vendas_df['Comissão'] = vendas_df['Valor Final'] * 0.05
valor_maior_que_90 = vendas_df.loc[vendas_df['Valor Final'] <= 50]
valor_maior_que_90['Imposto'] = valor_maior_que_90['Valor Final'] * 0.3
display(valor_maior_que_90)
# Out:
# C:\Users\M-PYTHON\AppData\Local\Temp\ipykernel_12144\735706221.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valor_maior_que_90['Imposto'] = valor_maior_que_90['Valor Final'] * 0.3
#        Código Venda       Data                     ID Loja        Produto  \
# 27               22 2019-01-02   Parque Dom Pedro Shopping           Meia
# 48               36 2019-01-02  Rio Mar Shopping Fortaleza  Meia Listrado
# 90               69 2019-01-02         Shopping Ibirapuera    Meia Xadrez
# 107              82 2019-01-02         Shopping Vila Velha  Meia Listrado
# 122              96 2019-01-02             Shopping Recife    Meia Xadrez
# ...             ...        ...                         ...            ...
# ...

# %%
valor_maior_50 = vendas_df[vendas_df['Valor Final'] > 50]
valor_maior_50['Imposto'] = valor_maior_50['Valor Final'] * 0.9
display(vendas_df)
# Out:
# C:\Users\M-PYTHON\AppData\Local\Temp\ipykernel_12144\3925601682.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valor_maior_50['Imposto'] = valor_maior_50['Valor Final'] * 0.9
#        Código Venda       Data              ID Loja            Produto  \
# 0                 1 2019-01-01   Iguatemi Esplanada     Sapato Estampa
# 1                 1 2019-01-01   Iguatemi Esplanada           Camiseta
# 2                 1 2019-01-01   Iguatemi Esplanada      Sapato Xadrez
# 3                 2 2019-01-02       Norte Shopping            Relógio
# 4                 2 2019-01-02       Norte Shopping       Chinelo Liso
# ...             ...        ...                  ...                ...
# ...
